# %% [markdown]
# # Stock Price Prediction

# %% [markdown]
# ## Karan Shingde - Data Science intern at LetsGrowMore(VIP) December 2021

# %% [markdown]
# **Task: Stock Market Prediction And Forecasting Using Stacked LSTM, by given data of a stock find the future prediction or stock forcasting with the help of graphs.**

# %% [markdown]
# ### Importing important libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

from pandas_datareader.data import DataReader

from datetime import datetime

# %% [markdown]
# **Collecting the data from given link**

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv')

# %%
df.head(10)
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
# 5  2018-09-21  235.00  237.00  227.95  233.75  234.60               5395319
# 6  2018-09-19  235.95  237.20  233.45  234.60  234.90               1362058
# 7  2018-09-18  237.90  239.25  233.50  235.50  235.05               2614794
# 8  2018-09-17  233.15  238.00  230.25  236.40  236.60               3170894
# 9  2018-09-14  223.45  236.70  223.30  234.00  233.95               6377909
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55
# ...

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# shape og the data
df.shape
# Out:
# (2035, 8)

# %%
# basic information of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2035 entries, 0 to 2034
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2035 non-null   object
#  1   Open                  2035 non-null   float64
#  2   High                  2035 non-null   float64
#  3   Low                   2035 non-null   float64
#  4   Last                  2035 non-null   float64
#  5   Close                 2035 non-null   float64
#  6   Total Trade Quantity  2035 non-null   int64
#  7   Turnover (Lacs)       2035 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 127.3+ KB

# %%
# some statistical asepcts of the data
df.describe()
# Out:
#               Open         High          Low         Last       Close  \
# count  2035.000000  2035.000000  2035.000000  2035.000000  2035.00000
# mean    149.713735   151.992826   147.293931   149.474251   149.45027
# std      48.664509    49.413109    47.931958    48.732570    48.71204
# min      81.100000    82.800000    80.000000    81.000000    80.95000
# 25%     120.025000   122.100000   118.300000   120.075000   120.05000
# 50%     141.500000   143.400000   139.600000   141.100000   141.25000
# 75%     157.175000   159.400000   155.150000   156.925000   156.90000
# max     327.700000   328.750000   321.650000   325.950000   325.75000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          2.035000e+03      2035.000000
# mean           2.335681e+06      3899.980565
# std            2.091778e+06      4570.767877
# min            3.961000e+04        37.040000
# 25%            1.146444e+06      1427.460000
# 50%            1.783456e+06      2512.030000
# ...

# %%
#checking number of null values
df.isnull().sum()
# Out:
# Date                    0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Close                   0
# Total Trade Quantity    0
# Turnover (Lacs)         0
# dtype: int64

# %% [markdown]
# **Okay, so there is no null value present in data so we can perform further analysis**

# %%
# Formatting date
df['Date'] = pd.to_datetime(df.Date,dayfirst=True)
df.set_index("Date", inplace=True)

# %%
df.head()
# Out:
#               Open    High     Low    Last   Close  Total Trade Quantity  \
# Date
# 2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#             Turnover (Lacs)
# Date
# 2018-09-28          7162.35
# 2018-09-27         11859.95
# 2018-09-26          5248.60
# 2018-09-25          5503.90
# 2018-09-24          7999.55

# %%
df.rename(columns={'Total Trade Quantity':'Volume'},inplace=True)

# %%
df.head(10)
# Out:
#               Open    High     Low    Last   Close   Volume  Turnover (Lacs)
# Date
# 2018-09-28  234.05  235.95  230.20  233.50  233.75  3069914          7162.35
# 2018-09-27  234.55  236.80  231.10  233.80  233.25  5082859         11859.95
# 2018-09-26  240.00  240.00  232.50  235.00  234.25  2240909          5248.60
# 2018-09-25  233.30  236.75  232.00  236.25  236.10  2349368          5503.90
# 2018-09-24  233.55  239.20  230.75  234.00  233.30  3423509          7999.55
# 2018-09-21  235.00  237.00  227.95  233.75  234.60  5395319         12589.59
# 2018-09-19  235.95  237.20  233.45  234.60  234.90  1362058          3202.78
# 2018-09-18  237.90  239.25  233.50  235.50  235.05  2614794          6163.70
# 2018-09-17  233.15  238.00  230.25  236.40  236.60  3170894          7445.41
# 2018-09-14  223.45  236.70  223.30  234.00  233.95  6377909         14784.50

# %%
# Convert time series to specified frequency.

# Returns the original data conformed to a new index with the specified frequency.
df = df.asfreq("d")
df = df.fillna(method='bfill')

# %%
# Plotting Open Prices
df['Open'].plot(figsize=(12,8))
plt.ylabel("Open Price")
# Out:
# Text(0, 0.5, 'Open Price')

# %%
# Plotting volume 
df['Volume'].plot(figsize=(12,8))
plt.ylabel("Volume Price")
# Out:
# Text(0, 0.5, 'Volume Price')

# %%
# plotting turnover in lacs
df['Turnover (Lacs)'].plot(figsize=(12,8))
plt.title('Turnver in Lacs')
# Out:
# Text(0.5, 1.0, 'Turnver in Lacs')

# %%
# Creating new columns 'Daily Return'
df['Daily Return'] = df['Turnover (Lacs)'].pct_change(1)

# %%
# Mean of Dailr Return
df['Daily Return'].mean()
# Out:
# 0.1715485974277474

# %%
SR = df['Daily Return'].mean()/df['Daily Return'].std()

# %%
df['Daily Return'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# plotting everything
all_plot = df/df.iloc[0]
all_plot.plot(figsize=(34,12))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.hist(bins=100, figsize=(12,6))
plt.tight_layout()

# %%
df.resample(rule='A').mean()
# Out:
#                   Open        High         Low        Last       Close  \
# Date
# 2010-12-31  120.939329  122.346646  118.601524  120.252134  120.207012
# 2011-12-31   95.471233   97.115616   93.640822   95.192740   95.179863
# 2012-12-31  127.971858  130.267213  125.606694  127.771311  127.686475
# 2013-12-31  146.456575  148.655753  143.882740  146.171644  146.108904
# 2014-12-31  154.245479  156.294795  152.229452  153.963973  153.985479
# 2015-12-31  141.318356  143.122603  139.264932  141.016986  141.076164
# 2016-12-31  127.978005  129.762842  126.102596  127.663115  127.666940
# 2017-12-31  181.826986  184.925342  179.349315  182.198493  182.196986
# 2018-12-31  266.087823  270.543911  261.596494  266.066052  265.938745
#
#                   Volume  Turnover (Lacs)  Daily Return
# Date
# 2010-12-31  1.154934e+06      1402.119451      0.206162
# 2011-12-31  1.212957e+06      1181.406301      0.233375
# 2012-12-31  2.461222e+06      3291.820656      0.246039
# ...

# %%
title = 'Yearly Mean Closing Price'
df['Open'].resample('A').mean().plot.bar(title=title,color=['#b41f7d'],figsize=(24,12) )
# Out:
# <AxesSubplot:title={'center':'Yearly Mean Closing Price'}, xlabel='Date'>

# %% [markdown]
# **Analysis of the stock on the basis of MOVING AVERAGES**

# %%
df['6-month-SMA'] = df['Open'].rolling(window=6).mean()
df['12-month-SMA'] = df['Open'].rolling(window=12).mean()
df['2-month-SMA'] = df['Open'].rolling(window=2).mean()

# %%
df[["Open","6-month-SMA","12-month-SMA","2-month-SMA"]].plot(figsize=(40,24));

# %%
df[["Open","6-month-SMA"]].plot(figsize=(18,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Opening price and 6 months moving averages on the basis of last 100 records
df[['Open','6-month-SMA']].iloc[:100].plot(figsize=(12,6)).autoscale(axis='x',tight=True);

# %% [markdown]
# **Exponentially Weighted Moving Average:
# The exponentially weighted moving average is widely used in computing the return volatility in risk management**

# %%
df['EWMA12'] = df['Open'].ewm(span=14,adjust=True).mean()

# %%
#open and ewma12 visuals
df[['Open', 'EWMA12']].plot(figsize=(24,12))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# last 50 records
df[['Open','EWMA12']].iloc[:50].plot(figsize=(12,6)).autoscale(axis='x',tight=True);

# %%
df['EWMA12'] = df['Open'].ewm(span=14,adjust=True).mean()

# %%
span = 8
alpha = 2/(span+1)

# %%
df['EWMA12'] = df['Open'].ewm(alpha=alpha, adjust=False).mean()

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %% [markdown]
# - What is Simple Exponential Smoothing?
# Single Exponential Smoothing, SES for short, also called Simple Exponential Smoothing, is a time series forecasting method for univariate data without a trend or seasonality. It requires a single parameter, called alpha (a), also called the smoothing factor or smoothing coefficient.
#
# - What is the exponential smoothing method?
# Exponential smoothing is a rule of thumb technique for smoothing time series data using the exponential window function. Whereas in the simple moving average the past observations are weighted equally, exponential functions are used to assign exponentially decreasing weights over time.

# %%
model = SimpleExpSmoothing(df['Open'])
fitted_model = model.fit(smoothing_level=alpha, optimized=False)
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(

# %%
fitted_model.fittedvalues
# Out:
# Date
# 2010-07-21    122.100000
# 2010-07-22    122.100000
# 2010-07-23    121.700000
# 2010-07-24    121.722222
# 2010-07-25    121.361728
#                  ...
# 2018-09-24    233.236756
# 2018-09-25    233.306366
# 2018-09-26    233.304951
# 2018-09-27    234.792740
# 2018-09-28    234.738798
# Freq: D, Length: 2992, dtype: float64

# %%
fitted_model.fittedvalues.shift(-1)
# Out:
# Date
# 2010-07-21    122.100000
# 2010-07-22    121.700000
# 2010-07-23    121.722222
# 2010-07-24    121.361728
# 2010-07-25    121.081344
#                  ...
# 2018-09-24    233.306366
# 2018-09-25    233.304951
# 2018-09-26    234.792740
# 2018-09-27    234.738798
# 2018-09-28           NaN
# Freq: D, Length: 2992, dtype: float64

# %%
# SimpleExpSmoothing
df['SES12'] = fitted_model.fittedvalues.shift(-1)

# %%
df[['Close', 'SES12']].plot(figsize=(30,15)).autoscale(axis='x', tight=True)

# %%
# Daily Exponential Smoothing - add
df['DESadd12'] = ExponentialSmoothing(df['Open'], trend='add').fit().fittedvalues.shift(-1)
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(

# %%
df.head()
# Out:
#              Open    High     Low    Last   Close    Volume  Turnover (Lacs)  \
# Date
# 2010-07-21  122.1  123.00  121.05  121.10  121.55  658666.0           803.56
# 2010-07-22  120.3  122.00  120.25  120.75  120.90  293312.0           355.17
# 2010-07-23  121.8  121.95  120.25  120.35  120.65  281312.0           340.31
# 2010-07-24  120.1  121.00  117.10  117.10  117.60  658440.0           780.01
# 2010-07-25  120.1  121.00  117.10  117.10  117.60  658440.0           780.01
#
#             Daily Return  6-month-SMA  12-month-SMA  2-month-SMA      EWMA12  \
# Date
# 2010-07-21           NaN          NaN           NaN          NaN  122.100000
# 2010-07-22     -0.558004          NaN           NaN       121.20  121.700000
# 2010-07-23     -0.041839          NaN           NaN       121.05  121.722222
# 2010-07-24      1.292057          NaN           NaN       120.95  121.361728
# 2010-07-25      0.000000          NaN           NaN       120.10  121.081344
#
# ...

# %%
df[['Open', 'SES12', 'DESadd12']].plot(figsize=(24,12))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df[['Open', 'EWMA12', 'DESadd12']].iloc[:200].plot(figsize=(12,6)).autoscale(axis='x', tight=True)

# %%
plt.figure(figsize=(16,6))
plt.title('Open Price History')
plt.plot(df['Open'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Open Price USD ($)', fontsize=18)
plt.show()

# %% [markdown]
# # Removing Moving Average related columns

# %%
df.isnull().sum()
# Out:
# Open                0
# High                0
# Low                 0
# Last                0
# Close               0
# Volume              0
# Turnover (Lacs)     0
# Daily Return        1
# 6-month-SMA         5
# 12-month-SMA       11
# 2-month-SMA         1
# EWMA12              0
# SES12               1
# DESadd12            1
# dtype: int64

# %%
df.drop(['Daily Return', '6-month-SMA','12-month-SMA', '12-month-SMA', '2-month-SMA','EWMA12','SES12', 'DESadd12' ], axis=1)
# Out:
#               Open    High     Low    Last   Close     Volume  Turnover (Lacs)
# Date
# 2010-07-21  122.10  123.00  121.05  121.10  121.55   658666.0           803.56
# 2010-07-22  120.30  122.00  120.25  120.75  120.90   293312.0           355.17
# 2010-07-23  121.80  121.95  120.25  120.35  120.65   281312.0           340.31
# 2010-07-24  120.10  121.00  117.10  117.10  117.60   658440.0           780.01
# 2010-07-25  120.10  121.00  117.10  117.10  117.60   658440.0           780.01
# ...            ...     ...     ...     ...     ...        ...              ...
# 2018-09-24  233.55  239.20  230.75  234.00  233.30  3423509.0          7999.55
# 2018-09-25  233.30  236.75  232.00  236.25  236.10  2349368.0          5503.90
# 2018-09-26  240.00  240.00  232.50  235.00  234.25  2240909.0          5248.60
# 2018-09-27  234.55  236.80  231.10  233.80  233.25  5082859.0         11859.95
# 2018-09-28  234.05  235.95  230.20  233.50  233.75  3069914.0          7162.35
#
# ...

# %% [markdown]
# # Scaling the data

# %%
df.head(10)
# Out:
#              Open    High     Low    Last   Close     Volume  Turnover (Lacs)  \
# Date
# 2010-07-21  122.1  123.00  121.05  121.10  121.55   658666.0           803.56
# 2010-07-22  120.3  122.00  120.25  120.75  120.90   293312.0           355.17
# 2010-07-23  121.8  121.95  120.25  120.35  120.65   281312.0           340.31
# 2010-07-24  120.1  121.00  117.10  117.10  117.60   658440.0           780.01
# 2010-07-25  120.1  121.00  117.10  117.10  117.60   658440.0           780.01
# 2010-07-26  120.1  121.00  117.10  117.10  117.60   658440.0           780.01
# 2010-07-27  117.6  119.50  112.00  118.80  118.65   586100.0           694.98
# 2010-07-28  118.0  120.50  117.20  118.15  118.25   835593.0           994.01
# 2010-07-29  112.5  121.70  112.50  117.50  116.60  2359134.0          2791.03
# 2010-07-30  116.5  118.00  114.60  115.85  116.05  2656191.0          3112.68
#
#             Daily Return  6-month-SMA  12-month-SMA  2-month-SMA      EWMA12  \
# Date
# ...

# %% [markdown]
# # LSTM

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# **Splitting data into training data by 'Open'**

# %%
data = df.filter(['Open'])

dataset = data.values

training_data_len = int(np.ceil( len(dataset) * .95 ))

training_data_len
# Out:
# 2843

# %%
# MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)

scaled_data
# Out:
# array([[0.16626115],
#        [0.15896188],
#        [0.16504461],
#        ...,
#        [0.64436334],
#        [0.62226277],
#        [0.6202352 ]])

# %%
scaled_data.shape
# Out:
# (2992, 1)

# %%
# Training data into X_train and Y_train
train_data = scaled_data[0:int(training_data_len)]

x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i,0])
    y_train.append(train_data[i,0])
    if i<= 61:
        print(x_train)
        print(y_train)
        print()
        

x_train, y_train = np.array(x_train), np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1],1))
# Out:
# [array([0.16626115, 0.15896188, 0.16504461, 0.15815085, 0.15815085,
#        0.15815085, 0.14801298, 0.14963504, 0.12733171, 0.14355231,
#        0.14679643, 0.14679643, 0.14679643, 0.15085158, 0.15166261,
#        0.14557989, 0.13381995, 0.12530414, 0.12530414, 0.12530414,
#        0.12895377, 0.13240065, 0.12935929, 0.13098135, 0.14132198,
#        0.14132198, 0.14132198, 0.12489862, 0.11780211, 0.11719384,
#        0.12530414, 0.13341444, 0.13341444, 0.13341444, 0.15145985,
#        0.14152474, 0.15044607, 0.15369019, 0.15287916, 0.15287916,
#        0.15287916, 0.14557989, 0.16443633, 0.17477697, 0.16788321,
#        0.17092457, 0.17092457, 0.17092457, 0.17396594, 0.19018654,
#        0.18896999, 0.19221411, 0.19221411, 0.19221411, 0.19221411,
#        0.18268451, 0.17741281, 0.17396594, 0.16909976, 0.16788321])]
# [0.16788321167883213]
#
# [array([0.16626115, 0.15896188, 0.16504461, 0.15815085, 0.15815085,
#        0.15815085, 0.14801298, 0.14963504, 0.12733171, 0.14355231,
# ...

# %% [markdown]
# ## Training LSTM model

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(LSTM(32, return_sequences=False))
model.add(Dense(16))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 60, 64)            16896
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dense (Dense)                (None, 16)                528
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# ...
# Total params: 29,857
# Trainable params: 29,857
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
callbacks = EarlyStopping(patience=3, monitor='val_loss', mode='min',verbose=1)

# %%
history = model.fit(x_train, y_train, epochs=20, batch_size=128, callbacks=[callbacks])
# Out:
# Epoch 1/20
# 22/22 [==============================] - 19s 171ms/step - loss: 0.0125
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 2/20
# 22/22 [==============================] - 5s 227ms/step - loss: 0.0011
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 3/20
# 22/22 [==============================] - 5s 215ms/step - loss: 6.7947e-04
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 4/20
# 22/22 [==============================] - 5s 227ms/step - loss: 5.9938e-04
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# Epoch 5/20
# 22/22 [==============================] - 6s 286ms/step - loss: 5.8272e-04
# ...

# %%
# test_data
from sklearn.metrics import mean_absolute_error
test_data = scaled_data[training_data_len - 60: , :]
x_test = []
y_test = dataset[training_data_len:, :]
for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])
    
# Convert the data to a numpy array
x_test = np.array(x_test)

# Reshape the data
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1 ))

# Get the models predicted price values 
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)

# Get the root mean squared error (RMSE)
rmse = np.sqrt(np.mean(((predictions - y_test) ** 2)))
print(rmse)
print(mean_absolute_error(y_test, predictions))
# Out:
# 9.421289586336773
# 6.712872990345793

# %%
# Plot the data
# train vs validation
train = data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = predictions
# Visualize the data
plt.figure(figsize=(16,6))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Open Price', fontsize=18)
plt.plot(train['Open'])
plt.plot(valid[['Open', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# C:\Users\Asus\AppData\Local\Temp/ipykernel_13648/1561907488.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predictions

# %%
valid[['Open','Predictions']].iloc[:250].plot(figsize=(12,6)).autoscale(axis='x',tight=True);

# %% [markdown]
# ## By the above forcasting graph we can see that our model performed very well ;)
#
# **Open price and prediction price are flowing hand by hand**
